# %%
import os
import sys
sys.path.insert(0, os.path.abspath("./tensortrade"))
import ta
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
import numpy as np

from tensortrade.feed.core import Stream, DataFeed, NameSpace
from tensortrade.oms.exchanges import Exchange
from tensortrade.oms.services.execution.simulated import execute_order
from tensortrade.oms.instruments import USD, BTC
from tensortrade.oms.wallets import Wallet, Portfolio
import tensortrade.env.default as default


from stable_baselines.common.policies import MlpLstmPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import A2C, PPO2

# %%
def load_csv(filename):
    data_path = os.path.abspath("./tensortrade/playground/data/")
    df = pd.read_csv(os.path.join(data_path,filename), skiprows=1)
    df.drop(columns=["symbol", "volume_btc"], inplace=True)
    # Fix timestamp form "2019-10-17 09-AM" to "2019-10-17 09-00-00 AM"
    df["date"] = df["date"].str[:14] + "00-00 " + df["date"].str[-2:]
    # Convert the date column type from string to datetime for proper sorting.
    df["date"] = pd.to_datetime(df["date"])
    # Make sure historical prices are sorted chronologically, oldest first.
    df.sort_values(by="date", ascending=True, inplace=True)
    df.reset_index(drop=True, inplace=True)
    # Format timestamps as you want them to appear on the chart buy/sell marks.
    df["date"] = df["date"].dt.strftime("%Y-%m-%d %I:%M %p")

    return df


def log_and_diff(df, cols):
    for col in cols:
        df[col] = np.log(df[col]) - np.log(df[col]).shift(1)

# %%
prices = load_csv("Coinbase_BTCUSD_1h.csv")
prices = prices.head(1000)
df = prices
print(df.head())
df.drop(columns=["date"], inplace=True)
df = ta.add_all_ta_features(df, "open", "high", "low", "close", "volume", fillna=True)
df = df + 1 - 2 * df.min()  # Make positive
log_and_diff(df, df.columns)
df.drop(df.index[:2], inplace=True)
prices.drop(prices.index[:2], inplace=True)
# Out:
#                   date     open     high      low    close     volume
# 0  2017-07-01 11:00 AM  2505.56  2513.38  2495.12  2509.17  287000.32
# 1  2017-07-01 12:00 PM  2509.17  2512.87  2484.99  2488.43  393142.50
# 2  2017-07-01 01:00 PM  2488.43  2488.43  2454.40  2454.43  693254.01
# 3  2017-07-01 02:00 PM  2454.43  2473.93  2450.83  2459.35  712864.80
# 4  2017-07-01 03:00 PM  2459.35  2475.00  2450.00  2467.83  682105.41
# /Users/bbevillard/Documents/Bev/Code/Python/Trading/.venv/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /Users/bbevillard/Documents/Bev/Code/Python/Trading/.venv/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# /Users/bbevillard/Documents/Bev/Code/Python/Trading/.venv/lib/python3.7/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/bbevillard/Documents/Bev/Code/Python/Trading/.venv/lib/python3.7/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.shape
# Out:
# (998, 88)

# %%
coinbase = Exchange("coinbase", service=execute_order)(
    Stream.source(prices["close"].tolist(), dtype="float").rename("USD-BTC")
)
portfolio = Portfolio(
    USD,
    [Wallet(coinbase, 10000 * USD), Wallet(coinbase, 0 * BTC)],
)


with NameSpace("coinbase"):
    streams = [Stream.source(df[c].tolist(), dtype="float").rename(c) for c in df.columns]
feed = DataFeed(streams)

# # Screen log

env = default.create(
    portfolio=portfolio,
    action_scheme=default.actions.SimpleOrders(),
    reward_scheme=default.rewards.SimpleProfit(),
    feed=feed,
    renderer="screen-log",  # ScreenLogger used with default settings
    window_size=2,
)
print(env.observation_space)
print(env.action_space)
# Out:
# Box(-inf, inf, (2, 88), float32)
# Discrete(21)

# %%
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.policies import MlpLstmPolicy
check_env(env)
# Out:
# /Users/bbevillard/Documents/Bev/Code/Python/Trading/.venv/lib/python3.7/site-packages/stable_baselines/common/env_checker.py:202: UserWarning: Your observation has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector
#   warnings.warn("Your observation has an unconventional shape (neither an image, nor a 1D vector). "

# %%
model = A2C(MlpLstmPolicy, env, verbose=1).learn(total_timesteps=10000)
# Out:
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | explained_variance | -4.86e+04 |
# | fps                | 16        |
# | nupdates           | 1         |
# | policy_entropy     | 3.04      |
# | total_timesteps    | 5         |
# | value_loss         | 0.00314   |
# ----------------------------------
# ---------------------------------
# | explained_variance | -9.92    |
# | fps                | 293      |
# | nupdates           | 100      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 500      |
# | value_loss         | 0.000437 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.72    |
# | fps                | 307      |
# | nupdates           | 200      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 1000     |
# | value_loss         | 0.00457  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -26.7    |
# | fps                | 329      |
# | nupdates           | 300      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 1500     |
# | value_loss         | 0.000797 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -39.8    |
# | fps                | 327      |
# | nupdates           | 400      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 2000     |
# | value_loss         | 0.00229  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.029    |
# | fps                | 333      |
# | nupdates           | 500      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 2500     |
# | value_loss         | 0.000345 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -11.3    |
# | fps                | 328      |
# | nupdates           | 600      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 3000     |
# | value_loss         | 0.000813 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.58    |
# | fps                | 333      |
# | nupdates           | 700      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 3500     |
# | value_loss         | 0.000757 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -851     |
# | fps                | 327      |
# | nupdates           | 800      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 4000     |
# | value_loss         | 0.0013   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.5     |
# | fps                | 327      |
# | nupdates           | 900      |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 4500     |
# | value_loss         | 0.000215 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -86.1    |
# | fps                | 324      |
# | nupdates           | 1000     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 5000     |
# | value_loss         | 0.000436 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -9.03    |
# | fps                | 327      |
# | nupdates           | 1100     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 5500     |
# | value_loss         | 0.000383 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -25.5    |
# | fps                | 324      |
# | nupdates           | 1200     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 6000     |
# | value_loss         | 0.000105 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -41.8    |
# | fps                | 325      |
# | nupdates           | 1300     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 6500     |
# | value_loss         | 0.000326 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -61.7    |
# | fps                | 321      |
# | nupdates           | 1400     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 7000     |
# | value_loss         | 0.00026  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.347   |
# | fps                | 322      |
# | nupdates           | 1500     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 7500     |
# | value_loss         | 0.000154 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -7.33    |
# | fps                | 322      |
# | nupdates           | 1600     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 8000     |
# | value_loss         | 0.000238 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -65.7    |
# | fps                | 322      |
# | nupdates           | 1700     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 8500     |
# | value_loss         | 0.000242 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -158     |
# | fps                | 323      |
# | nupdates           | 1800     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 9000     |
# | value_loss         | 0.000205 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.63    |
# | fps                | 320      |
# | nupdates           | 1900     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 9500     |
# | value_loss         | 0.000112 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -731     |
# | fps                | 320      |
# | nupdates           | 2000     |
# | policy_entropy     | 3.04     |
# | total_timesteps    | 10000    |
# | value_loss         | 0.000102 |
# ---------------------------------

# %%
model = PPO2(MlpLstmPolicy, env, verbose=1, nminibatches=1).learn(total_timesteps=1000)
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /Users/bbevillard/Documents/Bev/Code/Python/Trading/.venv/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /Users/bbevillard/Documents/Bev/Code/Python/Trading/.venv/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# --------------------------------------
# | approxkl           | 1.1316652e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.02         |
# | fps                | 30            |
# | n_updates          | 1             |
# | policy_entropy     | 3.044346      |
# | policy_loss        | -0.0030572973 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.31e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 0.00016125702 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.862817e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.21         |
# | fps                | 240           |
# | n_updates          | 2             |
# | policy_entropy     | 3.0443256     |
# | policy_loss        | -0.0010505458 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.19          |
# | total_timesteps    | 256           |
# | value_loss         | 0.00036529667 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.1017192e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.636        |
# | fps                | 224           |
# | n_updates          | 3             |
# | policy_entropy     | 3.0442848     |
# | policy_loss        | -0.0011085924 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 4.72          |
# | total_timesteps    | 384           |
# | value_loss         | 0.0006885975  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.3377152e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.756        |
# | fps                | 207           |
# | n_updates          | 4             |
# | policy_entropy     | 3.044294      |
# | policy_loss        | -0.0007877392 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 5.29          |
# | total_timesteps    | 512           |
# | value_loss         | 0.00038839344 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6650307e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.41         |
# | fps                | 200           |
# | n_updates          | 5             |
# | policy_entropy     | 3.0442083     |
# | policy_loss        | -0.0009562948 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 5.91          |
# | total_timesteps    | 640           |
# | value_loss         | 0.00049172435 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.0197662e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -7.53          |
# | fps                | 249            |
# | n_updates          | 6              |
# | policy_entropy     | 3.0441396      |
# | policy_loss        | -0.00090733124 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 6.55           |
# | total_timesteps    | 768            |
# | value_loss         | 0.00023358258  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.2281802e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.33         |
# | fps                | 248           |
# | n_updates          | 7             |
# | policy_entropy     | 3.0441966     |
# | policy_loss        | -0.0006869985 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 7.07          |
# | total_timesteps    | 896           |
# | value_loss         | 0.0002457682  |
# --------------------------------------
